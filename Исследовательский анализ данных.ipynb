# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Вам нужно научиться определять рыночную стоимость объектов недвижимости. Для этого проведите исследовательский анализ данных и установите параметры, влияющие на цену объектов. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта и других объектов — эти данные автоматически получены из геосервисов. Количество парков и водоёмов также заполняется без участия пользователя.

# %% [markdown]
# Инструкция по выполнению проекта
#
# Шаг 1. Откройте файл с данными и изучите общую информацию
#
# - Путь к файлу: /datasets/real_estate_data.csv
# - Скачать датасет
# - Загрузите данные из csv-файла в датафрейм c помощью библиотеки pandas.
# - Изучите общую информацию о полученном датафрейме.
# - Постройте гистограмму для всех числовых столбцов таблицы на одном графике. Например, для датафрейма data можно построить такую гистограмму командой data.hist(figsize=(15, 20)). Напомним, что параметр figsize задаёт размер графика.
#
# Шаг 2. Выполните предобработку данных
#
# - Найдите и изучите пропущенные значения в столбцах:
# - Определите, в каких столбцах есть пропуски.
# - Заполните пропущенные значения там, где это возможно. Например, если продавец не указал число балконов, то, скорее всего, в его квартире их нет. Такие пропуски можно заменить на число 0. Если логичную замену предложить невозможно, то оставьте пропуски. Пропущенные значения — тоже важный сигнал, который нужно учитывать.
# - В ячейке с типом markdown укажите причины, которые могли привести к пропускам в данных.
# - Рассмотрите типы данных в каждом столбце:
# - Найдите столбцы, в которых нужно изменить тип данных.
# - В ячейке с типом markdown поясните, почему нужно изменить тип данных.
# - Изучите уникальные значения в столбце с названиями и устраните неявные дубликаты. Например, «поселок Рябово» и «поселок городского типа Рябово», «поселок Тельмана» и «посёлок Тельмана» — это обозначения одних и тех же населённых пунктов. Вы можете заменить названия в существующем столбце или создать новый с названиями без дубликатов.
#
# Шаг 3. Добавьте в таблицу новые столбцы со следующими параметрами:
# - цена одного квадратного метра (нужно поделить стоимость объекта на его общую площадь, а затем округлить до двух знаков после запятой);
# - день недели публикации объявления (0 — понедельник, 1 — вторник и так далее);
# - месяц публикации объявления;
# - год публикации объявления;
# - тип этажа квартиры (значения — «‎первый», «последний», «другой»);
# - расстояние до центра города в километрах (переведите из м в км и округлите до ближайших целых значений).
#
# Шаг 4. Проведите исследовательский анализ данных:
# - Изучите перечисленные ниже параметры объектов и постройте отдельные гистограммы для каждого из этих параметров. В некоторых параметрах встречаются редкие и выбивающиеся значения. При построении гистограмм удалите их. Например, в столбце ceiling_height может быть указана высота потолков 25 м и 32 м. Логично предположить, что на самом деле это вещественные значения: 2.5 м и 3.2 м. Попробуйте обработать аномалии в этом и других столбцах, если они есть. Если природа аномалии понятна и данные действительно искажены, то восстановите    корректное значение. В противном случае удалите редкие и выбивающиеся значения.
#
# Список параметров:
# - общая площадь;
# - жилая площадь;
# - площадь кухни;
# - цена объекта;
# - количество комнат;
# - высота потолков;
# - тип этажа квартиры («первый», «последний», «другой»);
# - общее количество этажей в доме;
# - расстояние до центра города в метрах;
# - расстояние до ближайшего парка.
#
# - Опишите все ваши наблюдения по параметрам в ячейке с типом markdown.
# - Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней было размещено каждое объявление.
# - Постройте гистограмму.
# - Посчитайте среднее и медиану.
# - В ячейке типа markdown опишите, сколько времени обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?
# - Определите факторы, которые больше всего влияют на общую (полную) стоимость объекта.
#
# Изучите, зависит ли цена от:
# - общей площади;
# - жилой площади;
# - площади кухни;
# - количества комнат;
# - этажа, на котором расположена квартира (первый, последний, другой);
# - даты размещения (день недели, месяц, год).
#
# - Постройте графики, которые покажут зависимость цены от указанных выше параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы.
# - Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений — постройте сводную таблицу с количеством объявлений и средней ценой квадратного метра для этих населенных пунктов. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра.
# - Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца locality_name и вычислите их среднюю стоимость на разном удалении от центра. Учитывайте каждый километр расстояния: узнайте среднюю цену квартир в одном километре от центра, в двух и так далее. Опишите, как стоимость объектов зависит от расстояния до центра города — постройте график изменения средней цены для каждого километра от центра Петербурга.
#
# Шаг 5. Напишите общий вывод
#
# - Опишите полученные результаты и зафиксируйте итоговый вывод проведённого исследования.
# - Оформление
# - Выполните задание в Jupyter Notebook. Заполните программный код в ячейках типа code, текстовые пояснения — в ячейках типа markdown. Примените форматирование и заголовки.
# - Описание данных
# - airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
# - balcony — число балконов
# - ceiling_height — высота потолков (м)
#  cityCenters_nearest — расстояние до центра города (м)
# - days_exposition — сколько дней было размещено объявление (от публикации до снятия)
# - first_day_exposition — дата публикации
# - floor — этаж
# - is_apartment — апартаменты (булев тип)
# - kitchen_area — площадь кухни в квадратных метрах (м²)
# - last_price — цена на момент снятия с публикации
# - living_area — жилая площадь в квадратных метрах (м²)
# - locality_name — название населённого пункта
# - open_plan — свободная планировка (булев тип)
# - parks_around3000 — число парков в радиусе 3 км
# - parks_nearest — расстояние до ближайшего парка (м)
# - ponds_around3000 — число водоёмов в радиусе 3 км
# - ponds_nearest — расстояние до ближайшего водоёма (м)
# - rooms — число комнат
# - studio — квартира-студия (булев тип)
# - total_area — общая площадь квартиры в квадратных метрах (м²)
# - total_images — число фотографий квартиры в объявлении

# %% [markdown]
# ### Откроем файл с данными и изучим общую информацию

# %% [markdown]
# #### Импортируем библиотеки и читаем нужный файл

# %%
import warnings
from datetime import datetime

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %% [markdown]
# #### Выводим информацию о данных

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# #### Уточняем количество явных дубликатов

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Строим гистограммы

# %%
data.hist(figsize=(15, 20))
# Out:
# array([[<AxesSubplot:title={'center':'total_images'}>,
#         <AxesSubplot:title={'center':'last_price'}>,
#         <AxesSubplot:title={'center':'total_area'}>,
#         <AxesSubplot:title={'center':'rooms'}>],
#        [<AxesSubplot:title={'center':'ceiling_height'}>,
#         <AxesSubplot:title={'center':'floors_total'}>,
#         <AxesSubplot:title={'center':'living_area'}>,
#         <AxesSubplot:title={'center':'floor'}>],
#        [<AxesSubplot:title={'center':'kitchen_area'}>,
#         <AxesSubplot:title={'center':'balcony'}>,
#         <AxesSubplot:title={'center':'airports_nearest'}>,
#         <AxesSubplot:title={'center':'cityCenters_nearest'}>],
#        [<AxesSubplot:title={'center':'parks_around3000'}>,
#         <AxesSubplot:title={'center':'parks_nearest'}>,
#         <AxesSubplot:title={'center':'ponds_around3000'}>,
#         <AxesSubplot:title={'center':'ponds_nearest'}>],
#        [<AxesSubplot:title={'center':'days_exposition'}>, <AxesSubplot:>,
# ...

# %% [markdown]
# *Вывод*

# %% [markdown]
# В полученых данных 23699 записи. Есть пропущенные значения и некорректный тип данных. Явные дубликаты отсутствуют. На основе выведеных гистограмм можно сделать вывод о наличии аномальных значений. Данных достаточно для исследования.

# %% [markdown]
# ### Выполните предобработку данных

# %% [markdown]
# #### Определяем, в каких столбцах есть пропуски

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# #### Исправляем пропуски и неточности данных

# %% [markdown]
# В данных обнаружен столбец с заглавными символами, исправим это

# %%
data.rename(columns = {'cityCenters_nearest':'city_centers_nearest'}, inplace = True )

# %% [markdown]
#  Изменим тип данных в нужных столбцах

# %%
data['total_images'] = data['total_images'].astype(int)

# %%
data['last_price'] = data['last_price'].astype(int)

# %% [markdown]
#  В столбцах жилой и нежилой площади не будем заполнять пропуски, так как объекты могут быть подсобками, или без балконов и туалетов. Мы не можем предугадать данные наверняка. Но добавим количество знаков после запятой в столбец с жилой площадью

# %%
data['total_area'].round(2)
# Out:
# 0        108.00
# 1         40.40
# 2         56.00
# 3        159.00
# 4        100.00
#           ...
# 23694    133.81
# 23695     59.00
# 23696     56.70
# 23697     76.75
# 23698     32.30
# Name: total_area, Length: 23699, dtype: float64

# %% [markdown]
# Исправим формат времени

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')
data['first_day_exposition'].unique()
# Out:
# array(['2019-03-07T00:00:00.000000000', '2018-12-04T00:00:00.000000000',
#        '2015-08-20T00:00:00.000000000', ...,
#        '2014-12-29T00:00:00.000000000', '2016-09-12T00:00:00.000000000',
#        '2015-07-19T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
data['rooms'].isna().sum()
# Out:
# 0

# %% [markdown]
#  В столбце с количеством комнат пропусков не выявлено. Тип данных соответствует необходимому (согласно общего среза). Оставим столбец неизменным

# %% [markdown]
#  В столбце с высотой потолков есть пропуски. Заменим NaN на медианное значение в ceiling_height

# %%
data['ceiling_height'] = data['ceiling_height'].fillna(data['ceiling_height'].median())
data['ceiling_height'].sort_values(ascending=False).head(20)
# Out:
# 22869    100.0
# 3148      32.0
# 22336     32.0
# 21377     27.5
# 4876      27.0
# 17857     27.0
# 5246      27.0
# 20478     27.0
# 22938     27.0
# 5807      27.0
# 21824     27.0
# 10773     27.0
# 5669      26.0
# 18545     25.0
# 4643      25.0
# 9379      25.0
# 11285     25.0
# 14382     25.0
# 355       25.0
# 6246      25.0
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Так же, замечены пропуски в столбце с количеством этажей. Так как пропусков всего 86, предлагаю исключить их из исследования, так как медиана может быть меньше, чем этаж, где продается квартира. Изменим тип данных

# %%
data.dropna(subset=['floors_total'], inplace=True)
data['floors_total'].astype('int').sort_values(ascending=False).head(10)
# Out:
# 2253     60
# 16731    52
# 16934    37
# 397      36
# 5807     36
# 11079    36
# 4855     35
# 18617    35
# 5808     35
# 13975    35
# Name: floors_total, dtype: int64

# %% [markdown]
#  В столбце аппартаменты аномальное количество пропусков. Предположительно из за того, что в данных просто не указали отличные данные. Например, квартира. Проверим эти данные, посчитав процент таких аппартаментов

# %%
data['is_apartment'].mean()
# Out:
# 0.018018018018018018

# %% [markdown]
# Всего 1.8% объектов являются аппартаментами. Считаю это допустимым. Заменим пропуски на False и изменим тип данных

# %%
data['is_apartment'] = data['is_apartment'].fillna(False).astype(bool)

# %%
data['studio'].isna().sum()
# Out:
# 0

# %%
data['open_plan'].isna().sum()
# Out:
# 0

# %% [markdown]
# В  столбцах аппартаменты и открытая планировка пропуски отсутствуют. Соггласно общему срезу, тип соответствующий. Оставим столбец без изменений

# %% [markdown]
# В столбце с площадью кухни обнаружено 2278 пропусков. Возможно собственники не указали наличие кухни, так как в квартире кухня-гостинная, или ее по просту нет. Чтобы понять, так ли это, построим корреляцию Пирсона

# %%
data.corr().sort_values(by='kitchen_area', ascending=False)['kitchen_area'].head(10)
# Out:
# kitchen_area        1.000000
# total_area          0.609468
# last_price          0.520018
# living_area         0.428768
# rooms               0.269672
# floors_total        0.163944
# ponds_around3000    0.150576
# floor               0.135486
# total_images        0.105773
# days_exposition     0.100641
# Name: kitchen_area, dtype: float64

# %% [markdown]
# Явной зависимости не прослеживается, поэтому заменим пустые значения на 0

# %%
data['kitchen_area'] = data['kitchen_area'].fillna(0)

# %% [markdown]
# В столбце с балконами почти половина данных отсутстует. Возможно из за отсутствия самих балконов в помещениях. Проверим это по аналогии с столбцом кухни

# %%
data.corr().sort_values(by='balcony', ascending=False)['balcony'].head(10)
# Out:
# balcony                 1.000000
# floors_total            0.194065
# floor                   0.173056
# total_images            0.117741
# kitchen_area            0.113714
# airports_nearest        0.066653
# parks_nearest           0.055314
# city_centers_nearest    0.051338
# total_area              0.049765
# ceiling_height          0.043021
# Name: balcony, dtype: float64

# %% [markdown]
# Явной зависимости не прослеживается, поэтому заменим пустые значения на 0, а так же изменим тип данных

# %%
data['balcony'] = data['balcony'].fillna(0)
data['is_apartment'] = data['is_apartment'].astype(int)

# %% [markdown]
# При анализе названия населенных пунктов, необходимо преобразовать весь текст в строчные символы, заменить ё на е, и изменить обозначения пгт и гп, так как они имеют одно значение. В списке встречаются идентичные названия деревни и поселка городского типа, но объединять данные считаю невозможным, так как это могут быть разные населенные пункты.

# %%
data['locality_name'] = data['locality_name'].str.lower()
data['locality_name'] = data['locality_name'].str.replace('ё', 'е')
data['locality_name'] = data['locality_name'].str.replace('городской поселок','поселок городского типа')
data['locality_name'].unique()
# Out:
# array(['санкт-петербург', 'поселок шушары',
#        'поселок городского типа янино-1', 'поселок парголово',
#        'поселок мурино', 'ломоносов', 'сертолово', 'петергоф', 'пушкин',
#        'деревня кудрово', 'коммунар', 'колпино',
#        'поселок городского типа красный бор', 'гатчина',
#        'деревня федоровское', 'выборг', 'кронштадт', 'кировск',
#        'деревня новое девяткино', 'поселок металлострой',
#        'поселок городского типа лебяжье',
#        'поселок городского типа сиверский', 'поселок молодцово',
#        'поселок городского типа кузьмоловский',
#        'садовое товарищество новая ропша', 'павловск',
#        'деревня пикколово', 'всеволожск', 'волхов', 'кингисепп',
#        'приозерск', 'сестрорецк', 'деревня куттузи', 'поселок аннино',
#        'поселок городского типа ефимовский', 'поселок плодовое',
#        'деревня заклинье', 'поселок торковичи', 'поселок первомайское',
#        'красное село', 'поселок понтонный', 'сясьстрой', 'деревня старая',
# ...

# %% [markdown]
# При анализе списка после изменений, разных названий с идентичной интерпритацией не обнаружено. В списке встречаются идентичные названия деревни и поселка городского типа, но объединять данные считаю невозможным, так как это могут быть разные населенные пункты.

# %% [markdown]
# Помимо интерпритаций, в столбце 49 пропусков. Считаю подставить данные невозможным и предлагаю заменить пропуски на unknown

# %%
data['locality_name'] = data['locality_name'].fillna('unknown')

# %% [markdown]
# В столбце с расстоянием до аэропорта присутствует 5542 пропуска. предположительно, отсутствие данных является следствием отсутствия аэропорта в городе, поэтому заменить данные мы не можем

# %% [markdown]
# В столбце с расстоянием до центра города так же есть пропуски. Скорее всего, они указывают,что объект продажи находится не в городе. Поэтому, так же оставим столбец без изменений

# %% [markdown]
# В столбце количество парков в радиусе 3000м 5518 пропусков. Предположим, что пропуски означают отсутствие парков в заданном радиусе и заменим их на 0, изменив тип данных

# %%
data['parks_around3000'] =data['parks_around3000'].fillna(0)
data['parks_around3000'] = data['parks_around3000'].astype(int)

# %% [markdown]
# А вот в столбце с расстоянием до ближайшего парка заменить пропуски нет возможности, так как не можем знать причину отсутствия данных. Возможно парки просту слишком далеко. Оставим столбец неизменным

# %% [markdown]
# В столбцах с колличеством водоемов в радиусе 3000м и расстоянием до ближайшего ситуация аналогичная с парками. Поэтому заменим пропуски в количестве парков на 0

# %%
data['ponds_around3000'] =data['ponds_around3000'].fillna(0)
data['ponds_around3000'] = data['ponds_around3000'].astype(int)

# %% [markdown]
# В столбце с датами публикации незаполненные пропуски скорее всего, указывают, что объект не продан и хотя присутствующие значения "Количество дней" являются целочисленными оставим пока столбец неизменным

# %% [markdown]
# #### Проверим все измененные данные:

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area              1870
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                     0
# locality_name               0
# airports_nearest         5532
# city_centers_nearest     5509
# parks_around3000            0
# parks_nearest           15568
# ponds_around3000            0
# ponds_nearest           14552
# days_exposition          3172
# dtype: int64

# %% [markdown]
# **Общие выводы по разделу**
#
# Основными причинами пропусков могли стать:
# - Человеческий фактор.
# - Несовершенство программной оболочки (не все поля обязательные, нет чекбоксов с выбором, нет проверки данных)
# - Возможны программные сбои
# - Доработка системы во время её работы (ранее введенные данные не откорректированы)

# %% [markdown]
# ### Добавьте в таблицу новые столбцы со следующими параметрами:

# %% [markdown]
# - цена одного квадратного метра (нужно поделить стоимость объекта на его общую площадь, а затем округлить до двух знаков после запятой);
# - день недели публикации объявления (0 — понедельник, 1 — вторник и так далее);
# - месяц публикации объявления;
# - год публикации объявления;

# %%
data['price_square_meter'] = (data['last_price'] / data['total_area']).round(2)
print(data['price_square_meter'].unique())

data['day_publication'] = data['first_day_exposition'].dt.weekday 
print(data['day_publication'].unique())

data['month_publication'] = data['first_day_exposition'].dt.month 
print(data['month_publication'].unique())

data['year_publication '] = data['first_day_exposition'].dt.year 
print(data['year_publication '].unique())
# Out:
# [120370.37  82920.79  92785.71 ...  44091.71 149511.4   41795.67]
# [3 1 4 0 2 6 5]
# [ 3 12  8  7  6  9 11  4  5  2  1 10]
# [2019 2018 2015 2017 2016 2014]

# %% [markdown]
# - тип этажа квартиры (значения — «‎первый», «последний», «другой»);

# %%
def floor(row):
    if row['floor'] == 1:
        return 'первый'
    if row['floor'] == row['floors_total']:
        return 'последний'
    else:
        return 'другой'

data['type_apartment_floor'] = data.apply(floor, axis=1) 
data['type_apartment_floor'].unique()
# Out:
# array(['другой', 'первый', 'последний'], dtype=object)

# %%
test = data[(data["rooms"] == 1)]
test.head()
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 1              7     3350000       40.40           2018-12-04      1
# 5             10     2890000       30.40           2018-09-10      1
# 6              6     3700000       37.30           2017-11-02      1
# 8             20     2900000       33.16           2018-05-23      1
# 10             5     5050000       39.60           2017-11-16      1
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 1             2.65          11.0        18.60      1             0  ...
# 5             2.65          12.0        14.40      5             0  ...
# 6             2.65          26.0        10.60      6             0  ...
# 8             2.65          27.0        15.43     26             0  ...
# 10            2.67          12.0        20.30      3             0  ...
#
#     parks_around3000  parks_nearest  ponds_around3000  ponds_nearest  \
# ...

# %% [markdown]
# - расстояние до центра города в километрах (переведите из м в км и округлите до ближайших целых значений).

# %%
data['distance_city_center'] = (data['city_centers_nearest'] / 1000).round().astype('Int64')
data['distance_city_center'].unique()
# Out:
# <IntegerArray>
# [  16,   19,   14,    7,    8, <NA>,   12,   15,   52,   33,   31,   11,   13,
#    10,    2,   32,    4,   17,   30,    5,   51,   50,   24,   18,    9,   28,
#     3,    6,   27,   21,   49,   35,   36,   34,    1,   29,   26,   53,   22,
#    55,   20,   23,   25,    0,   66,   47,   40,   57,   37,   41,   43,   48,
#    62,   60,   39,   42,   65,   54,   59,   45,   61,   63]
# Length: 62, dtype: Int64

# %% [markdown]
# Проверим наши изменения

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 3             0    64900000       159.0           2015-07-24      3
# 4             2    10000000       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70          16.0         51.0      8             0  ...
# 1            2.65          11.0         18.6      1             0  ...
# 2            2.65           5.0         34.3      4             0  ...
# 3            2.65          14.0          NaN      9             0  ...
# 4            3.03          14.0         32.0     13             0  ...
#
#    parks_nearest  ponds_around3000  ponds_nearest  days_exposition  \
# ...

# %% [markdown]
# #### **Изучение и описание зависимости количества квартир в продаже от отдельных параметров**

# %% [markdown]
# ##### Анализ общей площади

# %%
data['total_area'].describe()
# Out:
# count    23613.000000
# mean        60.340678
# std         35.648988
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.800000
# max        900.000000
# Name: total_area, dtype: float64

# %% [markdown]
# Оставим значения от минимального 12 до 100 кв. метров, построим гистограмму:

# %%
plt.hist(data['total_area'], bins=100, range=(12,100))
plt.title('Зависимость квартир в продаже от площади квартир')
plt.xlabel('Квадратные метры')
plt.ylabel('Количество квартир')
plt.show()

# %% [markdown]
#  *Вывод:*
#
# Согласно исследованию, максимальное количество объявлений о продаже квартир с общей площадью от 40 до 65 кв. метров, с максимумом около 50 кв. метров.
# Согласно жилищному кодексу, норма жилой площади на одного человека составляет 33 м². Для двоих человек норма составляет 42 м². Для семьи из троих человек и более каждому положено минимум 18 м². По статистике, в РФ чаще владельцами квартир являются семейные пары с 1 ребенком, что подтверждает наши выводы.

# %% [markdown]
# ##### Анализ жилой площади

# %%
data['living_area'].describe()
# Out:
# count    21743.000000
# mean        34.462781
# std         22.037433
# min          2.000000
# 25%         18.600000
# 50%         30.000000
# 75%         42.300000
# max        409.700000
# Name: living_area, dtype: float64

# %% [markdown]
# Оставим значения от минимального 2 до 50 кв. метров построим гистограмму

# %%
plt.hist(data['living_area'], bins=100, range=(2,50))
plt.title('Зависимость квартир в продаже от жилой площади квартир')
plt.xlabel('Квадратные метры')
plt.ylabel('Количество квартир')
plt.show()

# %% [markdown]
# *Вывод*
#
# Согласно исследованию, максимальное количество объявлений о продаже квартир с жилой площадью около 18 кв. м и 30 кв. метров, при этом прослеживается спад предложений в средней зоне 23 кв. метра.
# Исходя из вывода, сделанного ранее, владельцы квартир с площадью до 30кв.м. одиноки, соответсвенно чаще меняют место своего проживания. Предположительно, это связано с отсутствием различных обременений.

# %% [markdown]
# ##### Анализ площади кухни

# %%
data['kitchen_area'].describe()
# Out:
# count    23613.000000
# mean         9.566009
# std          6.412137
# min          0.000000
# 25%          6.300000
# 50%          9.000000
# 75%         11.420000
# max        112.000000
# Name: kitchen_area, dtype: float64

# %% [markdown]
# Оставим значения от минимального 0 до 15 кв. метров, построим гистограмму

# %%
plt.hist(data['kitchen_area'], bins=100, range=(0,15))
plt.title('Зависимость квартир в продаже от площади кухни')
plt.xlabel('Квадратные метры')
plt.ylabel('Количество квартир')
plt.show()

# %% [markdown]
# *Вывод*
#
# Согласно исследованию, максимальное количество объявлений о продаже квартир - без кухни, более двух тысяч. Предположительно, это связано с количеством гостинок и секционок на рынке в общей сложности. Также, прослеживается тенденция, что больше всего предложений с площадью кухни в 6 метров, что является стандартом с "Сталинках и Хрущевках", затем 10 и после 7,8,9 кв. метров, при этом заметны явные всплески на целых числах.

# %% [markdown]
# ##### Анализ цены объекта

# %%
data['last_price'].describe()
# Out:
# count    2.361300e+04
# mean     6.540555e+06
# std      1.090172e+07
# min      1.219000e+04
# 25%      3.400000e+06
# 50%      4.650000e+06
# 75%      6.799000e+06
# max      7.630000e+08
# Name: last_price, dtype: float64

# %% [markdown]
# Оставим значения от минимального 0 млн.руб. до 7.630000e+08 млн.руб., построим гистограмму

# %%
plt.hist(data['last_price'], bins=100, range=(1.219000e+04,7.630000e+06))
plt.title('Зависимость квартир в продаже от цены объекта')
plt.xlabel('Цена в млн. руб.')
plt.ylabel('Количество квартир')
plt.show()

# %% [markdown]
# *Вывод*
#
# Согласно исследованию, максимальное количество объявлений о продаже квартир с ценой от 3.5 млн.руб. до 4.5 млн.руб. Если сравнить гистограммы общей площади квартир и цены объекта, то прослеживается зависимость цены квартиры к цене за кв.м.

# %% [markdown]
# ##### Анализ количество комнат

# %%
data['rooms'].describe()
# Out:
# count    23613.000000
# mean         2.071147
# std          1.078380
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: rooms, dtype: float64

# %% [markdown]
# Оставим значения от минимального 0 до 8 комнат, построим гистограмму

# %%
data.query('0 <= rooms <= 8').groupby(by='rooms')['rooms'].count().plot(kind='bar', ylabel = 'count');
plt.title('Зависимость квартир в продаже от комнат')
plt.xlabel('Количество комнат')
plt.ylabel('Количество квартир')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# *Вывод*
#
# Согласно исследованию, максимальное количество объявлений о продаже однокомнатных квартир, почти 8000. Почти столько же продают двухкомнатных. По результатам анализа гистограммы прослеживается зависимость количества квартир на рынке от количества комнат. Чем больше комнат в квартире, тем меньше их на рынке.

# %% [markdown]
# ##### Анализ высоты потолков

# %%
data['ceiling_height'].describe()
# Out:
# count    23613.000000
# mean         2.724581
# std          0.990085
# min          1.000000
# 25%          2.600000
# 50%          2.650000
# 75%          2.700000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Оставим значения от минимального 2,5 м до 3 м, построим гистограмму

# %%
plt.hist(data['ceiling_height'], bins=100, range=(2.5,3))
plt.title('Зависимость квартир в продаже от высоты потолков')
plt.xlabel('Высота потолков')
plt.ylabel('Количество квартир')
plt.show()

# %% [markdown]
# *Вывод*
#
# Согласно исследованию, максимальное количество объявлений о продаже квартир с стандартной высотой потолка 2.65 м, их почти половина от всего рынка. После идут квартиры с высотой потолка 2.5 м, 2.6м, 2.7м, 3м.

# %% [markdown]
# ##### Анализ типа этажа квартиры («первый», «последний», «другой»)

# %%
data['floor'].describe()
# Out:
# count    23613.000000
# mean         5.877313
# std          4.873539
# min          1.000000
# 25%          2.000000
# 50%          4.000000
# 75%          8.000000
# max         33.000000
# Name: floor, dtype: float64

# %%
plt.hist(data['type_apartment_floor'], bins=100, )
plt.title('Зависимость квартир в продаже от этажности')
plt.xlabel('Этаж')
plt.ylabel('Количество квартир')
plt.show()

# %% [markdown]
# *Вывод*
#
# По результатам анализа гистограммы квартир на первом и поледнем этаже продается примерно одинаковое количество. Проводить анализ  категории других этажей считаю нецелесообразным, так как в данной категории находится сумма всех остальных этажей и перебивает результаты количеством.

# %% [markdown]
# ##### Анализ общего количество этажей в доме

# %%
data['floors_total'].describe()
# Out:
# count    23613.000000
# mean        10.673824
# std          6.597173
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         60.000000
# Name: floors_total, dtype: float64

# %% [markdown]
# Оставим значения от минимального 1 до 30 этажей в доме, построим гистограмму

# %%
plt.hist(data['floors_total'], bins=100, range=(1,30))
plt.title('Зависимость квартир в продаже от общего количество этажей в доме')
plt.xlabel('Количество этажей в доме')
plt.ylabel('Количество квартир')
plt.show()

# %% [markdown]
# *Вывод*
#
# Согласно исследованию, максимальное количество объявлений о продаже квартир с 5 этажами. После, с 9, 16 и 25 этажами. Связано это с стандартами строительства домов. Чаще всего происходят возведение домов именно с такими этажностями из за стабильности зданий на определенных высотах.

# %% [markdown]
# ##### Анализ расстояния до центра города в метрах

# %%
data['city_centers_nearest'].describe()
# Out:
# count    18104.000000
# mean     14185.084015
# std       8614.132292
# min        181.000000
# 25%       9233.750000
# 50%      13093.000000
# 75%      16287.000000
# max      65968.000000
# Name: city_centers_nearest, dtype: float64

# %% [markdown]
# Оставим значения от минимального 181м до 30000м до центра города, построим гистограмму

# %%
plt.hist(data['city_centers_nearest'], bins=100, range=(181,30000))
plt.title('Зависимость квартир в продаже от расстояния до центра города в метрах')
plt.xlabel('Расстояние до центра города в метрах')
plt.ylabel('Количество квартир')
plt.show()

# %% [markdown]
# Увеличим для более точного понимания

# %%
plt.hist(data['city_centers_nearest'], bins=100, range=(4500,16000))
plt.title('Зависимость квартир в продаже от расстояния до центра города в метрах')
plt.xlabel('Расстояние до центра города в метрах')
plt.ylabel('Количество квартир')
plt.show()

# %% [markdown]
# *Вывод*
#
# Согласно исследованию, максимальное количество объявлений о продаже квартир, расположенных на расстоянии от центра города примерно  в 12000-14700м. Чуть меньше, на расстоянии в 4100м. Что позволяет сделать выводы о нежелании населения проживать в шумной и не экологичной среде.

# %% [markdown]
# ##### Расстояние до ближайшего парка

# %%
data['parks_nearest'].describe()
# Out:
# count    8045.000000
# mean      490.554630
# std       341.336698
# min         1.000000
# 25%       288.000000
# 50%       455.000000
# 75%       612.000000
# max      3190.000000
# Name: parks_nearest, dtype: float64

# %% [markdown]
# Оставим значения от минимального 1м до 1000м до до ближайшего парка, построим гистограмму

# %%
plt.hist(data['parks_nearest'], bins=100, range=(1,1000))
plt.title('Зависимость квартир в продаже от расстояния до до ближайшего парка')
plt.xlabel('Расстояние до до ближайшего парка в метрах')
plt.ylabel('Количество квартир')
plt.show()

# %% [markdown]
# *Вывод*
#
# Согласно исследованию, максимальное количество объявлений о продаже квартир с парками в радиусе 400-500м. Среднее расстояние до ближайшего парка варьируется от 200м до 600м, что является почти половиной всего исследования. Считаю, что  для населения более важны другие параметры подбора жилья, например удаленность метро или инфраструктура района.

# %% [markdown]
# **Общие выводы по разделу**
#
# 1. Согласно исследованию, максимальное количество объявлений о продаже квартир с общей площадью от 40 до 65 кв. метров, с максимумом около 50 кв. метров. Согласно жилищному кодексу, норма жилой площади на одного человека составляет 33 м². Для двоих человек норма составляет 42 м². Для семьи из троих человек и более каждому положено минимум 18 м². По статистике, в РФ чаще владельцами квартир являются семейные пары с 1 ребенком, что подтверждает наши выводы.
# 2. Согласно исследованию, максимальное количество объявлений о продаже квартир с жилой площадью около 18 кв. м и 30 кв. метров, при этом прослеживается спад предложений в средней зоне 23 кв. метра. Исходя из вывода, сделанного ранее, владельцы квартир с площадью до 30кв.м. одиноки, соответсвенно чаще меняют место своего проживания. Предположительно, это связано с отсутствием различных обременений.
# 3. Согласно исследованию, максимальное количество объявлений о продаже квартир - без кухни, более двух тысяч. Предположительно, это связано с количеством гостинок и секционок на рынке в общей сложности. Также, прослеживается тенденция, что больше всего предложений с площадью кухни в 6 метров, что является стандартом с "Сталинках и Хрущевках", затем 10 и после 7,8,9 кв. метров, при этом заметны явные всплески на целых числах.
# 4. Согласно исследованию, максимальное количество объявлений о продаже квартир с ценой от 3.5 млн.руб. до 4.5 млн.руб. Если сравнить гистограммы общей площади квартир и цены объекта, то прослеживается зависимость цены квартиры к цене за кв.м.
# 5. Согласно исследованию, максимальное количество объявлений о продаже однокомнатных квартир, почти 8000. Почти столько же продают двухкомнатных. По результатам анализа гистограммы прослеживается зависимость количества квартир на рынке от количества комнат. Чем больше комнат в квартире, тем меньше их на рынке.
# 6. Согласно исследованию, максимальное количество объявлений о продаже квартир с стандартной высотой потолка 2.65 м, их почти половина от всего рынка. После идут квартиры с высотой потолка 2.5 м, 2.6м, 2.7м, 3м.
# 7. По результатам анализа гистограммы квартир на первом и поледнем этаже продается примерно одинаковое количество. Проводить анализ  категории других этажей считаю нецелесообразным, так как в данной категории находится сумма всех остальных этажей и перебивает результаты количеством.
# 8. Согласно исследованию, максимальное количество объявлений о продаже квартир с 5 этажами. После, с 9, 16 и 25 этажами. Связано это с стандартами строительства домов. Чаще всего происходят возведение домов именно с такими этажностями из за стабильности зданий на определенных высотах.
# 9. Согласно исследованию, максимальное количество объявлений о продаже квартир, расположенных на расстоянии от центра города примерно  в 12000-14700м. Чуть меньше, на расстоянии в 4100м. Что позволяет сделать выводы о нежелании населения проживать в шумной и не экологичной среде.
# 10. Согласно исследованию, максимальное количество объявлений о продаже квартир с парками в радиусе 400-500м. Среднее расстояние до ближайшего парка варьируется от 200м до 600м, что является почти половиной всего исследования. Считаю, что  для населения более важны другие параметры подбора жилья, например удаленность метро или инфраструктура района.
#
# Сопоставим данные и выведем самые частые параметры при продаже квартиры:
# - квартира в пятиэтажном доме
# - средняя общая площадь 50 кв.м
# - без кухни или с кухней в 6 кв.м
# - высота потолков 2,65 метра
# - однокомнатная или двухкомнатная с маленькими комнатками
# - на удалении 13 км от центра города.

# %% [markdown]
# #### **Изучаем, как быстро продавались квартиры**

# %%
print('Расчитаем показатели')
print(data['days_exposition'].describe())
# Out:
# Расчитаем показатели
# count    20441.000000
# mean       180.884839
# std        219.685543
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        232.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
plt.hist(data['days_exposition'], bins=100, range=(0,250))
plt.title('Распределение количества продаж по времени')
plt.xlabel('Сколько дней было размещено объявление (от публикации до снятия)')
plt.ylabel('Количество объявлений')
plt.show()

# %% [markdown]
# *Вывод*
#
# Средняя длительность продажи квартиры занимает 180 дней, при том, что медианное значение составляет 95 дня. В данном случае медиана показывает более точное значение. Срок продажи зависит от площади, цены, удалённости от центра.

# %% [markdown]
# ##### **Определим факторы, которые больше всего влияют на общую стоимость объекта**
# общей площади;
# жилой площади;
# площади кухни;
# количества комнат;
# этажа, на котором расположена квартира (первый, последний, другой);
# даты размещения (день недели, месяц, год).

# %%
data[['last_price', 'total_area', 'rooms', 'living_area']].corr()
# Out:
#              last_price  total_area     rooms  living_area
# last_price     1.000000    0.653581  0.363124     0.566396
# total_area     0.653581    1.000000  0.758324     0.939770
# rooms          0.363124    0.758324  1.000000     0.846006
# living_area    0.566396    0.939770  0.846006     1.000000

# %% [markdown]
# ##### Проведем обработку полученых значений

# %%
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23613.000000  2.361300e+04  23613.000000  23613.000000    23613.000000
# mean       9.874518  6.540555e+06     60.340678      2.071147        2.724581
# std        5.681541  1.090172e+07     35.648988      1.078380        0.990085
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.600000
# 50%        9.000000  4.650000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.799000e+06     69.800000      3.000000        2.700000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  is_apartment  kitchen_area  \
# count  23613.000000  21743.000000  23613.000000  23613.000000  23613.000000
# mean      10.673824     34.462781      5.877313      0.002117      9.566009
# ...

# %% [markdown]
# - Количество фото - 0, оставим столбец без изменений.
# - Минимальная цена 12000, видимо квартира планировалась к сдаче, а не продаже. Так же как и продавец с квартирой за миллиард, видимо ошибся нулями. Исключим такие выбросы.
# - Минимальная площадь квартиры 12м2, это допустимо. Однако максимум слишком велик. Срежем до 400м2.
# - Столбец с комнатами оставим без изменений. Ведь у нас есть аппартаменты и гостинки. И 7-комнатные квартиры встречаются в любом городе.
# - С потолкми проведем несколько корректировок: удаляем квартиры с высотой потолков до 2.2м, от 4м до 25м. А высота потолков с 25 до 32 метров предполагаем, что это опечатка и делим на 10, получая 2.5 и 3.2 метра.
# - В стролбцах с этажностью находятся  с 1 по 60 этаж. Приемлимые цифры, изменять не будем.
# - Минимум жилой площади составляем 2м2, что является невозможным в РФ. Начнем наши рассчеты с 10м2.
# - Количество этажей от 1 до 33, оставим столбец без изменений.
# - Удалим строки с кухнами менее 2м2 и больше 50м2.
# - Балконы оставим без изменений.

# %%
data.drop(index=data.query('last_price < 1e+06 or last_price > 2.5e+07').index, inplace=True)
data.drop(index=data.query('last_price > 2.5e+07').index,inplace=True)
data.drop(index=data.query('total_area > 400').index,inplace=True)
data.drop(index=data.query('ceiling_height < 2.2 or ceiling_height > 4').index, inplace=True)
data.update(data[(data['ceiling_height'] >= 25) & (data['ceiling_height'] <= 32)]['ceiling_height']/10)

# %%
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  22851.000000  2.285100e+04  22851.000000  22851.000000    22851.000000
# mean       9.836243  5.644082e+06     57.722910      2.031771        2.688313
# std        5.647475  3.634103e+06     26.507967      1.011551        0.195796
# min        0.000000  1.000000e+06     12.000000      0.000000        2.200000
# 25%        6.000000  3.450000e+06     40.000000      1.000000        2.600000
# 50%        9.000000  4.600000e+06     51.400000      2.000000        2.650000
# 75%       14.000000  6.600000e+06     68.000000      3.000000        2.700000
# max       50.000000  2.500000e+07    363.000000     14.000000        4.000000
#
#        floors_total   living_area         floor  is_apartment  kitchen_area  \
# count  22851.000000  21088.000000  22851.000000  22851.000000  22851.000000
# mean      10.796683     33.069450      5.916940      0.001707      9.315591
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22851 entries, 0 to 23698
# Data columns (total 28 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          22851 non-null  int64
#  1   last_price            22851 non-null  int64
#  2   total_area            22851 non-null  float64
#  3   first_day_exposition  22851 non-null  datetime64[ns]
#  4   rooms                 22851 non-null  int64
#  5   ceiling_height        22851 non-null  float64
#  6   floors_total          22851 non-null  float64
#  7   living_area           21088 non-null  float64
#  8   floor                 22851 non-null  int64
#  9   is_apartment          22851 non-null  int64
#  10  studio                22851 non-null  bool
#  11  open_plan             22851 non-null  bool
#  12  kitchen_area          22851 non-null  float64
#  13  balcony               22851 non-null  float64
# ...

# %% [markdown]
# После корректировки данных, результаты выглядят более приземленно.

# %%
data.pivot_table(index='last_price', values=['living_area','total_area','kitchen_area','rooms','type_apartment_floor', 'days_exposition']).corr()
# Out:
#                  days_exposition  kitchen_area  living_area     rooms  \
# days_exposition         1.000000      0.169896     0.133665  0.134354
# kitchen_area            0.169896      1.000000     0.423559  0.324759
# living_area             0.133665      0.423559     1.000000  0.904805
# rooms                   0.134354      0.324759     0.904805  1.000000
# total_area              0.166115      0.505654     0.941527  0.844035
#
#                  total_area
# days_exposition    0.166115
# kitchen_area       0.505654
# living_area        0.941527
# rooms              0.844035
# total_area         1.000000

# %% [markdown]
# - Цена по убыванию зависит от:
#
# общей площади;
# жилой площади;
# площади кухни;
# количества комнат.
# - Цена практически на зависит от:
#
# этажа, на котором расположена квартира;
# даты размещения.
#
# Про остальные значения можно сказать: Прямой зависимости нет.

# %% [markdown]
# ##### Изучим более подробно зависимости цены

# %%
(data.pivot_table(index='total_area', values='last_price').plot(grid=True, style='o', figsize=(5, 5)))
plt.title('Зависимость цены от общей площади')
plt.xlabel('Общая площадь')
plt.ylabel('Цена')
plt.show()

# %% [markdown]
# При увеличении площади квартиры, растет и ее стоимость.

# %%
(
    data.pivot_table(index='living_area', values='last_price')
    .plot(grid=True, style='o', figsize=(5, 5))
)
plt.title('Зависимость цены от жилой площади')
plt.xlabel('Жилая площадь')
plt.ylabel('Цена')
plt.show()

# %% [markdown]
# При увеличении жилой площади квартиры, растет и ее стоимость. Но зависимость меньще, чем с общей площадью.

# %%
(
    data.pivot_table(index='kitchen_area', values='last_price')
    .plot(grid=True, style='o', figsize=(5, 5))
)
plt.title('Зависимость цены от площади кухни')
plt.xlabel('Площадь кухни')
plt.ylabel('Цена')
plt.show()

# %% [markdown]
# При вуеличении размеров кухни, стоимость квартиры меняется незначительно. Предположительно, что в больших квартирах присутствуют большие кухни и от сюда выходит большая стоимость

# %%
(
    data.pivot_table(index='rooms', values='last_price')
    .plot(grid=True, style='o', figsize=(5, 5))
)
plt.title('Зависимость цены от числа комнат')
plt.xlabel('Число комнат')
plt.ylabel('Цена')
plt.show()

# %% [markdown]
# Чем больше комнат, тем выше стоимость квартиры. Однако зависимость ниже, чем у площади.Количество комнат в отдаленных от центра районах стоит гораздо дешевле, чем в центре.

# %%
(
    data.pivot_table(index='type_apartment_floor', values='last_price')
    .plot(grid=True, style='o-', figsize=(5, 5))
)
plt.title('Зависимость цены от типа этажа расположения')
plt.xlabel('Этаж')
plt.ylabel('Цена')
plt.show()

# %% [markdown]
# Самые дешевые квартиры продаются на 1 этаже. А вот самыми дорогим считаются так называемые пентхаусы.

# %%
(
    data.pivot_table(index='day_publication', values='last_price')
    .plot(grid=True, style='o-', figsize=(5, 5))
)
plt.title('Зависимость цены от дня публикации')
plt.xlabel('День публикации')
plt.ylabel('Цена')
plt.show()

# %% [markdown]
# Дороже всего квартиры, опубликованные в пятницу, дешевле всего - в субботу.

# %%
(
    data.pivot_table(index='month_publication', values='last_price')
    .plot(grid=True, style='o-', figsize=(5, 5))
)
plt.title('Зависимость цены от месяца публикации')
plt.xlabel('Месяц публикации')
plt.ylabel('Цена')
plt.show()

# %% [markdown]
# Дороже всего квартиры, продающиеся с декабря, дешевле всего - с октября.

# %%
(
    data.pivot_table(index='year_publication ', values='last_price')
    .plot(grid=True, style='o-', figsize=(5, 5))
)
plt.title('Зависимость цены от года публикации')
plt.xlabel('Год публикации')
plt.ylabel('Цена')
plt.show()

# %% [markdown]
# Цены на квартиры падали с 2014 года, что было вызвано кризисом 2014-2015 годов. С 2018 года цены снова стали повышаться, но предыдущих результатов не достигло.

# %% [markdown]
# **Общий вывод по разделу**
#
# - При увеличении площади квартиры, растет и ее стоимость.
#
# - При увеличении жилой площади квартиры, растет и ее стоимость. Но зависимость меньще, чем с общей площадью.
#
# - При вуеличении размеров кухни, стоимость квартиры меняется незначительно. Предположительно, что в больших квартирах присутствуют большие кухни и от сюда выходит большая стоимость
#
# - Чем больше комнат, тем выше стоимость квартиры. Однако зависимость ниже, чем у площади.Количество комнат в отдаленных от центра районах стоит гораздо дешевле, чем в центре.
#
# - Самые дешевые квартиры продаются на 1 этаже. А вот самыми дорогим считаются так называемые пентхаусы.
#
# - Дороже всего квартиры, опубликованные в пятницу, дешевле всего - в субботу.
#
# - Дороже всего квартиры, продающиеся с декабря, дешевле всего - с октября.
#
# - Цены на квартиры падали с 2014 года, что было вызвано кризисом 2014-2015 годов. С 2018 года цены снова стали повышаться, но предыдущих результатов не достигло.

# %% [markdown]
# #### Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений — постройте сводную таблицу с количеством объявлений и средней ценой квадратного метра для этих населенных пунктов.

# %%
price_sm_name = data.pivot_table(index='locality_name', values='last_price', aggfunc=['count'])
price_sm_name.columns = ['count']
price_sm_name = price_sm_name.sort_values(by='count', ascending=False).head(10)
price_sm_name['price_square_meter'] = data.pivot_table(index='locality_name', values='price_square_meter').round(2)
price_sm_name.sort_values(by='price_square_meter', ascending=False)
# Out:
#                    count  price_square_meter
# locality_name
# санкт-петербург    15148           109681.12
# пушкин               361           102080.09
# деревня кудрово      299            92473.55
# поселок парголово    327            90175.91
# поселок мурино       550            85603.64
# поселок шушары       439            78551.34
# колпино              337            75333.30
# гатчина              305            68947.38
# всеволожск           395            68735.64
# выборг               230            58741.82

# %% [markdown]
# Самый дорогой м2 приходится на Санкт-Петербург, где численность объявлений занримает около 70% от всех данных.После, идет Пушкин, что является элитным района Питера. а самый дешевый м2 находится в Выборге.

# %% [markdown]
# #### Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца locality_name и вычислите их среднюю стоимость на разном удалении от центра. Учитывайте каждый километр расстояния: узнайте среднюю цену квартир в одном километре от центра, в двух и так далее. Опишите, как стоимость объектов зависит от расстояния до центра города — постройте график изменения средней цены для каждого километра от центра Петербурга.

# %%
data.query('locality_name == "санкт-петербург"')['distance_city_center'].describe()
# Out:
# count    15100.000000
# mean        11.772715
# std          4.773525
# min          0.000000
# 25%          9.000000
# 50%         12.000000
# 75%         15.000000
# max         29.000000
# Name: distance_city_center, dtype: float64

# %%
(
    data.query('locality_name == "санкт-петербург"')
    .pivot_table(index='distance_city_center', values='last_price')
    .plot(grid=True, style='o-', xlim=(0,15), figsize=(10, 5))
)
plt.title('Зависимость цены от удаления от центра города в Санкт-Петербурге')
plt.xlabel('Расстояние от центра города (километр)')
plt.ylabel('Цена (млн. руб.)')
plt.show()

# %%
data.query('locality_name == "санкт-петербург" and distance_city_center<10').dropna(subset=['last_price']).pivot_table(values='last_price', index='distance_city_center')
# Out:
#                         last_price
# distance_city_center
# 0                     9.981667e+06
# 1                     1.115317e+07
# 2                     1.080410e+07
# 3                     9.544514e+06
# 4                     9.926557e+06
# 5                     1.017197e+07
# 6                     9.179389e+06
# 7                     8.554440e+06
# 8                     8.487948e+06
# 9                     6.583768e+06

# %% [markdown]
# #### Общие выводы
#
# В процессе исследования объявлений о продаже квартир были сделаны следующие выводы:
#
#
# Самые частые параметры при продаже квартиры:
# - квартира в пятиэтажном доме
# - средняя общая площадь 50 кв.м
# - без кухни или с кухней в 6 кв.м
# - высота потолков 2,65 метра
# - однокомнатная или двухкомнатная с маленькими комнатками
# - на удалении 13 км от центра города.
#
# Срок продажи квартиры
#
# Средняя длительность продажи квартиры занимает 180 дней, при том, что медианное значение составляет 95 дня. В данном случае медиана показывает более точное значение. Срок продажи зависит от площади, цены, удалённости от центра.
#
# Факторы, влияющие на стоимость
#
# - При увеличении площади квартиры, растет и ее стоимость.
# - При увеличении жилой площади квартиры, растет и ее стоимость. Но зависимость меньще, чем с общей площадью.
# - При вуеличении размеров кухни, стоимость квартиры меняется незначительно. Предположительно, что в больших квартирах присутствуют большие кухни и от сюда выходит большая стоимость
# - Чем больше комнат, тем выше стоимость квартиры. Однако зависимость ниже, чем у площади.Количество комнат в отдаленных от центра районах стоит гораздо дешевле, чем в центре.
# - Самые дешевые квартиры продаются на 1 этаже. А вот самыми дорогим считаются так называемые пентхаусы.
# - Дороже всего квартиры, опубликованные в пятницу, дешевле всего - в субботу.
# - Дороже всего квартиры, продающиеся с декабря, дешевле всего - с октября.
# - Цены на квартиры падали с 2014 года, что было вызвано кризисом 2014-2015 годов. С 2018 года цены снова стали повышаться, но предыдущих результатов не достигло.
#
# Стоимость квадратного метра в топ-10 населённых пунктов
#
# - Дороже всего квадратный метр в Санкт-Петербурге - 114848
# - Дешевле всего квадратный метр в Выборге - 58141
